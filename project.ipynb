# %% [markdown]
# # Fundamentals of Data Analysis - Project
# ## Project Aims
# This project aims to "create a notebook investigating the variables and data points within the well-known iris flower data set associated with Ronald A Fisher."

# %%
# Import libraries to be used in this notebook

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Create a pandas dataframe of the dataset to be analysed.

df = pd.read_csv('data/iris/iris.data', names=('sepal length', 'sepal width', 'petal length', 'petal width', 'species'))
df.shape
# Out:
# (150, 5)

# %% [markdown]
# The above df.shape output shows us that the dataset has 5 columns and 150 rows
# ***
# ## Distribution
#
# The following section will look at how the values are distributed. This will include both aggregate distributions and distributions for individual species.
#
# ***
# ### Sepal Width
#
# The first variable to be examined is the Sepal Width.

# %%
plt.hist(df['sepal width'])
plt.title('Sepal Width - All Species')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The above histogram of sepal width across all species shows that sepal widths are mostly close to the central value of 3cm. The distribution of sepal widths does not conform to a normal distirbution, but rather seems to be more heavily weighted towards lower values.

# %%
setosa = df[df['species']=='Iris-setosa']
plt.hist(setosa['sepal width'], color='b')
plt.title('Sepal Width - Iris-setosa')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The above histogram for Sepal Width in the Iris-setosa shows that the measurements here are still centrall focused, with the majority within the range of 3cm-3.5cm. The distribution here is different to the overall distribution as the values are weighted towards the higher end of the scale, rather than the lower as is generally the case across Iris species.

# %%
versicolor = df[df['species']=='Iris-versicolor']
plt.hist(versicolor['sepal width'], color='orange')
plt.title('Sepal Width - Iris-versicolor')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The above histogram shows again a fairly centralised distribution of values, mostly congregated around 2.8cm-3cm. In contrast to the Iris-setosa, the Iris-versicolor is weighted towards the lower end of the scale with another peak in valuesaround 2.3cm.

# %%
virginica = df[df['species']=='Iris-virginica']
plt.hist(virginica['sepal width'], color='g')
plt.title('Sepal Width - Iris-virginica')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The above histogram again shows a heavy central weighting, mostly around 2.7cm-3.1cm. Unlike the other two specis the Iris-virginica does not have much weighting towards the upper or lower end of the scale outside of the central focus.
#
# ***
# ### Sepal Length
#
# The second variable to be examined is the Sepal Length.

# %%
plt.hist(df['sepal length'])
plt.title('Sepal Length - All Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The histogram of all sepal lengths shows a more even distribution than that of the sepal widths. Values vary between 4.5cm and just below 8cm. There is more of a weighting towards the lower end of the scale and less of a focus on central values.

# %%
plt.hist(setosa['sepal length'], color='b')
plt.title('Sepal Length - Iris-setosa')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The Iris-setosa has a distribution centred around 5cm without a prominent weighting towards lower or upper values. The distribution is not dissimilar to a normal distribution, however there are more values furthest from the central point than would be expected of a normal distribution.

# %%
plt.hist(versicolor['sepal length'], color='orange')
plt.title('Sepal Length - Iris-versicolor')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The sepal lengths of the Iris-versicolor are most prominently clustered around 5.6cm, with far more values above this point than below.

# %%
plt.hist(virginica['sepal length'], color='g')
plt.title('Sepal Length - Iris-virginica')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The Iris-virginica sepal lengths are focused mostly in the range of 6cm-7cm with few values outside of this. No prominent weighting up or down is visible.
# ***
#
# ### Petal Width
#
# The third variable to be examined is the petal width.

# %%
plt.hist(setosa['petal width'], color='b')
plt.title('Petal Width - Iris-setosa')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The majority of petal width for the Iris-setosa can be seen to be within the 0.2cm to 0.3cm range with a few outliers.

# %%
plt.hist(versicolor['petal width'], color='orange')
plt.title('Petal Width - Iris-versicolor')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Petal width for the Iris-versicolor show more wode distributionj than the Iris-setosa, with many samples clustered roughly around the centre. Unusually compared to other examples, there are no samples with a width in the centre of the distribution itself.

# %%
plt.hist(virginica['petal width'], color='g')
plt.title('Petal Width - Iris-virginica')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The distribution of petal widths for the Iris-virginica is mostly centred around 1.9cm with a slight weighting towards the higher end of the distribution.
# ***
#
# ### Petal Lengths

# %%
plt.hist(setosa['petal length'], color='b')
plt.title('Petal Length - Iris-setosa')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The distribution of petal lengths for the Iris-setosa is somewhat similar to a normal distribution, however it is much steeper than would be expected on a normal distribution.

# %%
plt.hist(versicolor['petal length'], color='orange')
plt.title('Petal Length - Iris-versicolor')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Petal lengths for the Iris-versicolor are centred on 4cm and heavily weighted towards the upper end of the scale.

# %%
plt.hist(virginica['petal length'], color='g')
plt.title('Petal Length - Iris-virginica')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Petal length for the Iris-virginica is centred on 5.6cm, has a peak at 5.1cm and doesn't appear to have any particular weighting towards the upper or lower end of the scale overall.
# ***
# ## Pairplot
#
# The pairplot below gives a more succinct and easy to read impresison of the dataset as a whole than the above histograms.

# %%
sns.pairplot(df, hue='species')
# Out:
# c:\Users\tombr\anaconda3\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# The above pairplot is a very useful tool for initial summary of a dataset.
#
# The pairplot plots each variable within the dataset with each other variable. By having each species of iris denoted by colour it becomes very clear that the species are generally seperable along each pair of variables.
#
# The most easily separable species is the iris-setosa, denoted above in blue. Looking at the above it can be seen that the iris-setosa has shorter and narrower petals than the other two species across all samples within this dataset.
#
# The iris-versicolor and iris-viriginica, orange and green respectively, also appear to form mostly distinct groupings according to sepal and petal measurements. However, as can be seen in all plots above there is some element of overlap across all variables between iris-versicolor and iris-virginica.
#
# ***
#
# ## Statistical Description
#
# This section will use df.describe() to get an overview of the dataset as a whole, and then by species.

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# The above description shows that there are no null values within the 150 rows.
#
# The mean figures above do not give a lot of information when taken on their own. However, we can see large differences in the standard deviations across the different variables.
#
# Sepal width has a standard deviation of 0.433594, implying that the values for all species are quite tightly clustered around the mean of 3.054cm.
#
# In comparison petal length has a standard deviation of 1.76442 showing a much larger spread of values around the mean of 3.758667cm.
#
# Below will look at individual species to see if results within species vary from what we have seen here.

# %%
setosa.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000

# %%
versicolor.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
virginica.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %% [markdown]
# In the above descriptions we can see that the petal length for any individual species does not have a standard deviation anywhere like as large as the dataset as a whole. It can be seen that the large standard deviation for the petal length overall was due to the large deviation between species. Viriginica having a mean petal length of 5.6cm and Setosa having a mean petal length of 1.5cm is likely to be the main driver of the large standard deviation when looking at the dataset as a whole.
#
# It can also be seen in these descriptions that across three out of four variables the Virginica has the highest mean. With Setosa having higher in sepal width.
#
# Similarly, Setosa can be seen to have the smallest mean in all variables other than sepal width.
#
# These simple observations imply that for classification purposes the irises are at least to a degree separable by size going Setosa, Versicolor, Virginica in ascending order. Of course, as can be seen in the pairplot above it is not quite as clean as to have an absolute divide across all variables.
#
# ***
